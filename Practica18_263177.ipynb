# %% [markdown]
# <a href="https://colab.research.google.com/github/ismael-almazan/Programaci-n-para-anal-tica-descriptiva-y-predictiva/blob/main/Practica18_263177.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Universidad Autonoma de Ciudad Juarez**
#
# **Maestría en Inteligencia Artificial y Analítica de Datos**
#
# **Programación para Analítica Descriptiva y Predictiva**
#
# **Ismael Almazan Luna**
#
# **12 de septiembre de 2025**

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import datetime as dt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Datos Temporales: Limpieza y Transformación
# El objetivo de esta actividad es que los estudiantes practiquen los temas vistos de limpieza y transformación de datos categóricos.

# %% [markdown]
# # Ejercicio 01:Tipo de Datos Correcto
# *  Carga el conjunto de datos airdata.csv y verifica que cada columna tenga el tipo de datos correcto
# *  Si una columna de tipo temporal no está en el tipo de correcto realiza la conversión.
# *  Usa dtypes para mostrar que cada columna, principalmente la que contiene datos temporales, está en el tipo de datos correcto
# *  Imprime las primeras tres líneas

# %%
#Cargar el dataset airtada.csv
df = pd.read_csv('/content/drive/MyDrive/Unidad02/Airdata.csv')

#Comprobar tipo de dato de la columna temportal
display(df.dtypes)

#Imprimir las primeras filas de DateTime (El formato esta en MM-DD-YYY, sin embargo, no en este caso no es necesareo especificar el formato, ya que automaticamente la  libreria la identidica
display(df.head(300))

#Convertir la columna de Datatime a formato de fecha
df['DateTime'] = pd.to_datetime(df['DateTime'])

#Imprimir para comprobar el tipo de dato nuevo
display(df.dtypes)

#Imprimir para comprobar los datos
display(df.head(300))
# Out:
# DateTime           object
# Temperature       float64
# Humidity            int64
# Wind_Speed        float64
# Wind_Direction    float64
# NO2_Location_A    float64
# NO2_Location_B    float64
# NO2_Location_C    float64
# dtype: object
#             DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0      1/1/2020 0:00     2.180529        87    1.484318       75.963760
# 1      1/1/2020 1:00     1.490529        89    2.741678      113.198590
# 2      1/1/2020 2:00     1.690529        85    3.563818      135.000000
# 3      1/1/2020 3:00     1.430529        84    2.811690      129.805570
# 4      1/1/2020 4:00     0.840529        86    1.800000      126.869896
# ..               ...          ...       ...         ...             ...
# 295   1/13/2020 7:00     4.770528        47    6.130579      130.236360
# 296   1/13/2020 8:00     4.820528        50    6.989936      124.508514
# 297   1/13/2020 9:00     4.510529        58    7.412853      119.054596
# ...

# %% [markdown]
# # Ejercicio 02: Extraer componentes de fecha y tiempo
#
# *  De la columna 'DateTime' extrae el año, mes, día y hora. Crea una nueva columna para cada componente que extraes
# *  Imprime las primeras tres líneas del dataframe que ahora deberá tener 4 nuevas columnas.

# %%
#Extraer de 'DateTime" por el año, med, dia y hora en nuevas columas
df['Year'] = df['DateTime'].dt.year
df['Month'] = df['DateTime'].dt.month
df['Day'] = df['DateTime'].dt.day
df['Hour'] = df['DateTime'].dt.hour

#Imprimir para comprobar los datos
display(df.head(3))
# Out:
#              DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0 2020-01-01 00:00:00     2.180529        87    1.484318        75.96376
# 1 2020-01-01 01:00:00     1.490529        89    2.741678       113.19859
# 2 2020-01-01 02:00:00     1.690529        85    3.563818       135.00000
#
#    NO2_Location_A  NO2_Location_B  NO2_Location_C  Year  Month  Day  Hour
# 0           39.23           52.88           62.37  2020      1    1     0
# 1           38.30           44.95           52.53  2020      1    1     1
# 2             NaN           48.40           54.80  2020      1    1     2

# %% [markdown]
# # Ejercicio 03: Aritmética - Suma de Intervalos (timedelta)
#
# *  Suma 10 días, 7 horas y 15 minutos a cada elemento de la columna 'DateTime'. * Guarda el resultado en una nueva columna y agrega al dataframe.
# *  Imprime la columna 'DateTime' y la columna que resulta de sumar 10 días, 7 horas y 15 minutos.

# %%
#Suma 10 días, 7 horas y 15 minutos a cada elemento de la columna 'DateTime' y Guarda el resultado en una nueva columna y agrega al dataframe.
df['DateTime_Futura'] = df['DateTime'] + pd.Timedelta(days=10, hours=7, minutes=15)

#Imprimir la columna DateTime y la  nueva columna columna
display(df[['DateTime', 'DateTime_Futura']])
# Out:
#                 DateTime     DateTime_Futura
# 0    2020-01-01 00:00:00 2020-01-11 07:15:00
# 1    2020-01-01 01:00:00 2020-01-11 08:15:00
# 2    2020-01-01 02:00:00 2020-01-11 09:15:00
# 3    2020-01-01 03:00:00 2020-01-11 10:15:00
# 4    2020-01-01 04:00:00 2020-01-11 11:15:00
# ...                  ...                 ...
# 8779 2020-12-31 19:00:00 2021-01-11 02:15:00
# 8780 2020-12-31 20:00:00 2021-01-11 03:15:00
# 8781 2020-12-31 21:00:00 2021-01-11 04:15:00
# 8782 2020-12-31 22:00:00 2021-01-11 05:15:00
# 8783 2020-12-31 23:00:00 2021-01-11 06:15:00
#
# [8784 rows x 2 columns]

# %% [markdown]
# # Ejercicio 04: Timestamp
#
# *  Convierte la columna 'DateTime' la cual tiene un formato de fecha legible a a timestamp Unix. Guarda el resultado en una nueva columna
# *  Imprime las primeras tres filas de  la columna 'DateTime' y la columna que representa dicha fecha en timestamp Unix

# %%
#Conviersion de la columna 'DateTime' a timestamp Unix
#display(df.dtypes)
#df['DateTimeUnix'] = df['DateTime'].timestamp()       #No se pudo con esta :(
df['DateTime_Unix'] = df['DateTime'].apply(lambda x: int(x.timestamp()))


#Imprimir las primeras tres filas de Datatime y la nueva Columna de Datatime en formato Unix
display(df[['DateTime', 'DateTime_Unix']].head(3))
# Out:
#              DateTime  DateTime_Unix
# 0 2020-01-01 00:00:00     1577836800
# 1 2020-01-01 01:00:00     1577840400
# 2 2020-01-01 02:00:00     1577844000

# %% [markdown]
# # Ejercicio 05: Filtrado de Fechas
#
# *  Utiliza la columna 'DateTime' y Filtra aquellas fechas que son mayores a 2020-11-01
# *  Imprime el resultado

# %%
#Fechas que son mayores a 2020-11-01
df_filtrado = df[df['DateTime'] > '2020-11-01']

#Imprimir el resultado
display(df_filtrado)
# Out:
#                 DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 7321 2020-11-01 01:00:00    13.620529        58    6.638072       130.60129
# 7322 2020-11-01 02:00:00    13.980529        40    6.618519       157.61987
# 7323 2020-11-01 03:00:00    13.010529        43    8.209263       164.74487
# 7324 2020-11-01 04:00:00    12.190529        51    7.568566       154.65382
# 7325 2020-11-01 05:00:00    12.510529        59    7.594208       148.57043
# ...                  ...          ...       ...         ...             ...
# 8779 2020-12-31 19:00:00     4.920528        72    4.553680       251.56506
# 8780 2020-12-31 20:00:00     4.990529        74    3.259939       186.34020
# 8781 2020-12-31 21:00:00     4.360529        84   10.587917       252.18112
# 8782 2020-12-31 22:00:00     3.820528        88    8.435069       219.80557
# 8783 2020-12-31 23:00:00     3.170529        89    6.792466       212.00539
#
# ...
